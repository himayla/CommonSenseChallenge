# %%
# Predictions for ensembling
import pandas as pd
from transformers import AutoTokenizer, AutoModelForMultipleChoice
import numpy as np
from sklearn.model_selection import train_test_split
import torch

CHECKPOINT = "checkpoint-1000"
BERT = "bert-base-uncased"

bert_tokenizer = AutoTokenizer.from_pretrained(BERT)
bert_model = AutoModelForMultipleChoice.from_pretrained(f"./results/{BERT}/{CHECKPOINT}/")

options = ["OptionA", "OptionB", "OptionC"]
answers = ['A', 'B', 'C']

# %%
def ensemble(example):
    prompts = []
    for opt in options:
        prompts.append([example['FalseSent'], example[opt]])
        
    print(prompts)

    bert_inputs = bert_tokenizer(prompts, return_tensors="pt", padding=True)

    labels = torch.tensor(0).unsqueeze(0)
    
    bert_outputs = bert_model(**{k: v.unsqueeze(0) for k, v in bert_inputs.items()}, labels=labels)

    predicted_class = bert_outputs.logits.argmax().item()

    return answers[predicted_class]

# %%
train_file = "common-sense/train_data.csv"
df_train = pd.read_csv(train_file)
ans_file = "common-sense/train_answers.csv"
df_ans = pd.read_csv(ans_file)
test_file = "common-sense/test_data.csv"
df_test = pd.read_csv(test_file)
X_train, X_test, y_train, y_test = train_test_split(df_train, df_ans['answer'], test_size=0.3, random_state=42)

X_train

    # submission_df = df_test[["id", "label"]].copy()
    # submission_df = submission_df.rename(columns={"label": "answer"})
    # submission_df.set_index("id", inplace=True)
    # submission_df.to_csv(f"submissions/Submission_12-12-2022_1.csv")
# Out:
#                  id                                          FalseSent  \
# 6760  sentence_6761                  He eats breakfast in the evening.
# 4623  sentence_4624                  Lilly barbecues fish in the water
# 7841  sentence_7842  I used to step on the mountain to get the suga...
# 3704  sentence_3705                      I saw a cow walking in a tree
# 981    sentence_982            Christmas is a time for working all day
# ...             ...                                                ...
# 5226  sentence_5227                        A strong wind kills people.
# 5390  sentence_5391                     Cruise ships can explore space
# 860    sentence_861  Justin Bieber is a famous musician who is not ...
# 7603  sentence_7604            I do homework every day to keep healthy
# 7270  sentence_7271                              he lent me some bills
#
#                                                 OptionA  \
# 6760               He goes to bed early in the evening.
# 4623                            fish lives in the water
# 7841      mountains are much more higher than cupboards
# 3704                    Cows can provide milk for human
# 981                 People eat big dinners on christmas
# ...                                                 ...
# 5226                     A strong wind will bring cool.
# 5390                              Cruise ships can sail
# 860   Justin Bieber and Mozart are musicians from di...
# 7603      doing homework can take up most time of a day
# 7270             he lent me some money to pay the bills
#
#                                                 OptionB  \
# 6760     Breakfast is very important to the human body.
# 4623                      fire can't exist in the water
# 7841                          it's wrong to steal sugar
# 3704                            Cows cannot climb trees
# 981                  People go on holidays at christmas
# ...                                                 ...
# 5226              Man cannot stand up in a strong wind.
# 5390                Cruise is a means of transportation
# 860   Justin Bieber was born in the last century and...
# 7603            doing homework can't make you healthier
# 7270  he gave me the bill because I've borrowed from...
#
#                                                 OptionC
# 6760                            Evening is dinner time.
# 4623                        barbecued fish is delicious
# 7841  it's impossible to know where the sugar is if ...
# 3704                       Cows can consume tree leaves
# 981        Typically, people have holidays on christmas
# ...                                                 ...
# 5226  A strong wind will blow people uncomfortable, ...
# 5390   Cruises ships are not allowed to go up to heaven
# 860    Justin Bieber is alive and still producing music
# 7603       doing homework is important to pass the exam
# 7270       bills need to be paid and are non-borrowable
#
# [5600 rows x 5 columns]

# %%
df_dr = X_train.apply(lambda row: ensemble(row), axis=1)

print(df_dr)
# Out:
# id                                            sentence_6761
# FalseSent                 He eats breakfast in the evening.
# OptionA                He goes to bed early in the evening.
# OptionB      Breakfast is very important to the human body.
# OptionC                             Evening is dinner time.
# Name: 6760, dtype: object
# [['He eats breakfast in the evening.', 'He goes to bed early in the evening.']]
# [['He eats breakfast in the evening.', 'He goes to bed early in the evening.'], ['He eats breakfast in the evening.', 'Breakfast is very important to the human body.']]
# [['He eats breakfast in the evening.', 'He goes to bed early in the evening.'], ['He eats breakfast in the evening.', 'Breakfast is very important to the human body.'], ['He eats breakfast in the evening.', 'Evening is dinner time.']]
# id                               sentence_4624
# FalseSent    Lilly barbecues fish in the water
# OptionA                fish lives in the water
# OptionB          fire can't exist in the water
# OptionC            barbecued fish is delicious
# Name: 4623, dtype: object
# [['Lilly barbecues fish in the water', 'fish lives in the water']]
# [['Lilly barbecues fish in the water', 'fish lives in the water'], ['Lilly barbecues fish in the water', "fire can't exist in the water"]]
# [['Lilly barbecues fish in the water', 'fish lives in the water'], ['Lilly barbecues fish in the water', "fire can't exist in the water"], ['Lilly barbecues fish in the water', 'barbecued fish is delicious']]
# id                                               sentence_7842
# FalseSent    I used to step on the mountain to get the suga...
# OptionA          mountains are much more higher than cupboards
# OptionB                              it's wrong to steal sugar
# OptionC      it's impossible to know where the sugar is if ...
# Name: 7841, dtype: object
# [['I used to step on the mountain to get the sugar on the op of the cupboard', 'mountains are much more higher than cupboards']]
# [['I used to step on the mountain to get the sugar on the op of the cupboard', 'mountains are much more higher than cupboards'], ['I used to step on the mountain to get the sugar on the op of the cupboard', "it's wrong to steal sugar"]]
# [['I used to step on the mountain to get the sugar on the op of the cupboard', 'mountains are much more higher than cupboards'], ['I used to step on the mountain to get the sugar on the op of the cupboard', "it's wrong to steal sugar"], ['I used to step on the mountain to get the sugar on the op of the cupboard', "it's impossible to know where the sugar is if parents hide it"]]
# id                             sentence_3705
# FalseSent      I saw a cow walking in a tree
# OptionA      Cows can provide milk for human
# OptionB              Cows cannot climb trees
# OptionC         Cows can consume tree leaves
# Name: 3704, dtype: object
# [['I saw a cow walking in a tree', 'Cows can provide milk for human']]
# [['I saw a cow walking in a tree', 'Cows can provide milk for human'], ['I saw a cow walking in a tree', 'Cows cannot climb trees']]
# [['I saw a cow walking in a tree', 'Cows can provide milk for human'], ['I saw a cow walking in a tree', 'Cows cannot climb trees'], ['I saw a cow walking in a tree', 'Cows can consume tree leaves']]
# id                                           sentence_982
# FalseSent         Christmas is a time for working all day
# OptionA               People eat big dinners on christmas
# OptionB                People go on holidays at christmas
# OptionC      Typically, people have holidays on christmas
# Name: 981, dtype: object
# [['Christmas is a time for working all day', 'People eat big dinners on christmas']]
# [['Christmas is a time for working all day', 'People eat big dinners on christmas'], ['Christmas is a time for working all day', 'People go on holidays at christmas']]
# [['Christmas is a time for working all day', 'People eat big dinners on christmas'], ['Christmas is a time for working all day', 'People go on holidays at christmas'], ['Christmas is a time for working all day', 'Typically, people have holidays on christmas']]
# id                                               sentence_6795
# FalseSent                        You can talk freely in class.
# OptionA             Students should listen carefully in class.
# OptionB      Speaking freely in class violates classroom di...
# OptionC                        We can talk freely in our home.
# Name: 6794, dtype: object
# [['You can talk freely in class.', 'Students should listen carefully in class.']]
# [['You can talk freely in class.', 'Students should listen carefully in class.'], ['You can talk freely in class.', 'Speaking freely in class violates classroom discipline.']]
# [['You can talk freely in class.', 'Students should listen carefully in class.'], ['You can talk freely in class.', 'Speaking freely in class violates classroom discipline.'], ['You can talk freely in class.', 'We can talk freely in our home.']]
# id                                sentence_2865
# FalseSent    A vulture was flying without wings
# OptionA       I played domino with the vultures
# OptionB           I saw a vulture born of a cow
# OptionC        A bird doesn't fly without wings
# Name: 2864, dtype: object
# [['A vulture was flying without wings', 'I played domino with the vultures']]
# [['A vulture was flying without wings', 'I played domino with the vultures'], ['A vulture was flying without wings', 'I saw a vulture born of a cow']]
# [['A vulture was flying without wings', 'I played domino with the vultures'], ['A vulture was flying without wings', 'I saw a vulture born of a cow'], ['A vulture was flying without wings', "A bird doesn't fly without wings"]]
# id                                               sentence_7063
# FalseSent    a giant panda is a black and white bird found ...
# OptionA                      a giant panda doesn't like flying
# OptionB                  a giant panda is a viviparous species
# OptionC        a giant panda is too heavy to be seen as a bird
# Name: 7062, dtype: object
# [['a giant panda is a black and white bird found in Asia', "a giant panda doesn't like flying"]]
# [['a giant panda is a black and white bird found in Asia', "a giant panda doesn't like flying"], ['a giant panda is a black and white bird found in Asia', 'a giant panda is a viviparous species']]
# [['a giant panda is a black and white bird found in Asia', "a giant panda doesn't like flying"], ['a giant panda is a black and white bird found in Asia', 'a giant panda is a viviparous species'], ['a giant panda is a black and white bird found in Asia', 'a giant panda is too heavy to be seen as a bird']]
# id                                               sentence_1269
# FalseSent              The baby drove all the way to Arkansas.
# OptionA                        A baby would cry the whole trip
# OptionB      Baby car seats are not meant for the drivers seat
# OptionC                              Babies do not drive cars.
# Name: 1268, dtype: object
# [['The baby drove all the way to Arkansas.', 'A baby would cry the whole trip']]
# [['The baby drove all the way to Arkansas.', 'A baby would cry the whole trip'], ['The baby drove all the way to Arkansas.', 'Baby car seats are not meant for the drivers seat']]
# [['The baby drove all the way to Arkansas.', 'A baby would cry the whole trip'], ['The baby drove all the way to Arkansas.', 'Baby car seats are not meant for the drivers seat'], ['The baby drove all the way to Arkansas.', 'Babies do not drive cars.']]
# id                                               sentence_7795
# FalseSent    a cup of coffee in the morning can make you sm...
# OptionA      coffee that can make you smarter is very expen...
# OptionB                      coffee can't improve intelligence
# OptionC               you can have a cup of coffee at any time
# Name: 7794, dtype: object
# [['a cup of coffee in the morning can make you smarter', 'coffee that can make you smarter is very expensive']]
# [['a cup of coffee in the morning can make you smarter', 'coffee that can make you smarter is very expensive'], ['a cup of coffee in the morning can make you smarter', "coffee can't improve intelligence"]]
# [['a cup of coffee in the morning can make you smarter', 'coffee that can make you smarter is very expensive'], ['a cup of coffee in the morning can make you smarter', "coffee can't improve intelligence"], ['a cup of coffee in the morning can make you smarter', 'you can have a cup of coffee at any time']]
# id                                                sentence_269
# FalseSent    You are likely to meet a car accident inside home
# OptionA              People don't drive cars inside their home
# OptionB                      Road is everywhere in the country
# OptionC                    People drive cars fast on the roads
# Name: 268, dtype: object
# [['You are likely to meet a car accident inside home', "People don't drive cars inside their home"]]
# [['You are likely to meet a car accident inside home', "People don't drive cars inside their home"], ['You are likely to meet a car accident inside home', 'Road is everywhere in the country']]
# [['You are likely to meet a car accident inside home', "People don't drive cars inside their home"], ['You are likely to meet a car accident inside home', 'Road is everywhere in the country'], ['You are likely to meet a car accident inside home', 'People drive cars fast on the roads']]
# id                                                sentence_655
# FalseSent                        The dog flew inside the house
# OptionA                 dogs never ever have wings or feathers
# OptionB      dogs usually walk inside of a house instead of...
# OptionC                                       a dog cannot fly
# Name: 654, dtype: object
# [['The dog flew inside the house', 'dogs never ever have wings or feathers']]
# [['The dog flew inside the house', 'dogs never ever have wings or feathers'], ['The dog flew inside the house', 'dogs usually walk inside of a house instead of flying.']]
# [['The dog flew inside the house', 'dogs never ever have wings or feathers'], ['The dog flew inside the house', 'dogs usually walk inside of a house instead of flying.'], ['The dog flew inside the house', 'a dog cannot fly']]
# id                                      sentence_2615
# FalseSent           She put on pants, then underwear.
# OptionA      Pants have pockets, but underwear don't.
# OptionB              Pants are longer than underwear.
# OptionC      Underwear has to be put on before pants.
# Name: 2614, dtype: object
# [['She put on pants, then underwear.', "Pants have pockets, but underwear don't."]]
# [['She put on pants, then underwear.', "Pants have pockets, but underwear don't."], ['She put on pants, then underwear.', 'Pants are longer than underwear.']]
# [['She put on pants, then underwear.', "Pants have pockets, but underwear don't."], ['She put on pants, then underwear.', 'Pants are longer than underwear.'], ['She put on pants, then underwear.', 'Underwear has to be put on before pants.']]
# id                                               sentence_2846
# FalseSent           Phone stores can be found inside salesmen.
# OptionA                    a building can't fit inside a human
# OptionB               Salesmen wear clothes while stores don't
# OptionC      salesmen living beings while stores are inanim...
# Name: 2845, dtype: object
# [['Phone stores can be found inside salesmen.', "a building can't fit inside a human"]]
# [['Phone stores can be found inside salesmen.', "a building can't fit inside a human"], ['Phone stores can be found inside salesmen.', "Salesmen wear clothes while stores don't"]]
# [['Phone stores can be found inside salesmen.', "a building can't fit inside a human"], ['Phone stores can be found inside salesmen.', "Salesmen wear clothes while stores don't"], ['Phone stores can be found inside salesmen.', 'salesmen living beings while stores are inanimate objects']]
# id                                  sentence_2918
# FalseSent        A tiger provides heat to a room.
# OptionA            A tiger does not provide heat.
# OptionB      A tiger is too big to fit in a room.
# OptionC       A tiger is too cold to heat a room.
# Name: 2917, dtype: object
# [['A tiger provides heat to a room.', 'A tiger does not provide heat.']]
# [['A tiger provides heat to a room.', 'A tiger does not provide heat.'], ['A tiger provides heat to a room.', 'A tiger is too big to fit in a room.']]
# [['A tiger provides heat to a room.', 'A tiger does not provide heat.'], ['A tiger provides heat to a room.', 'A tiger is too big to fit in a room.'], ['A tiger provides heat to a room.', 'A tiger is too cold to heat a room.']]
# id                                               sentence_5595
# FalseSent                                Nuts can be recycled.
# OptionA           Nuts are useless, so they can't be recycled.
# OptionB      Recycling and not littering nuts are environme...
# OptionC      Recycling reusable nuts can be used to plant t...
# Name: 5594, dtype: object
# [['Nuts can be recycled.', "Nuts are useless, so they can't be recycled."]]
# [['Nuts can be recycled.', "Nuts are useless, so they can't be recycled."], ['Nuts can be recycled.', 'Recycling and not littering nuts are environmentally friendly things.']]
# [['Nuts can be recycled.', "Nuts are useless, so they can't be recycled."], ['Nuts can be recycled.', 'Recycling and not littering nuts are environmentally friendly things.'], ['Nuts can be recycled.', 'Recycling reusable nuts can be used to plant trees.']]
# id                                         sentence_3488
# FalseSent    You may find a stone in the washing machine
# OptionA          Washing machine is heavier than a stone
# OptionB            Stone can't break the washing machine
# OptionC       The washing machine is bigger than a stone
# Name: 3487, dtype: object
# [['You may find a stone in the washing machine', 'Washing machine is heavier than a stone']]
# [['You may find a stone in the washing machine', 'Washing machine is heavier than a stone'], ['You may find a stone in the washing machine', "Stone can't break the washing machine"]]
# [['You may find a stone in the washing machine', 'Washing machine is heavier than a stone'], ['You may find a stone in the washing machine', "Stone can't break the washing machine"], ['You may find a stone in the washing machine', 'The washing machine is bigger than a stone']]
# id                                                sentence_590
# FalseSent                           He won the whole universe.
# OptionA      Universe is wide while winning a 100 dollars i...
# OptionB                                Universe cannot be won.
# OptionC                           Universe cannot eat dollars.
# Name: 589, dtype: object
# [['He won the whole universe.', 'Universe is wide while winning a 100 dollars is a great luck.']]
# [['He won the whole universe.', 'Universe is wide while winning a 100 dollars is a great luck.'], ['He won the whole universe.', 'Universe cannot be won.']]
# [['He won the whole universe.', 'Universe is wide while winning a 100 dollars is a great luck.'], ['He won the whole universe.', 'Universe cannot be won.'], ['He won the whole universe.', 'Universe cannot eat dollars.']]
# id                                               sentence_4547
# FalseSent    If you want to see penguins in the wild, you s...
# OptionA               The penguins in Africa all live in zoos.
# OptionB        The penguins in Antarctica are all native born.
# OptionC      Like many animals in Africa, penguins cannot fly.
# Name: 4546, dtype: object
# [['If you want to see penguins in the wild, you should go to Africa.', 'The penguins in Africa all live in zoos.']]
# [['If you want to see penguins in the wild, you should go to Africa.', 'The penguins in Africa all live in zoos.'], ['If you want to see penguins in the wild, you should go to Africa.', 'The penguins in Antarctica are all native born.']]
# [['If you want to see penguins in the wild, you should go to Africa.', 'The penguins in Africa all live in zoos.'], ['If you want to see penguins in the wild, you should go to Africa.', 'The penguins in Antarctica are all native born.'], ['If you want to see penguins in the wild, you should go to Africa.', 'Like many animals in Africa, penguins cannot fly.']]
# id                                               sentence_6415
# FalseSent    When the fruits are ripe in autumn, they don't...
# OptionA            The fruit is delicious when ripe in autumn.
# OptionB      If the fruit is not picked in time, it will fa...
# OptionC          Autumn is the harvest season for some fruits.
# Name: 6414, dtype: object
# [["When the fruits are ripe in autumn, they don't need to be harvested", 'The fruit is delicious when ripe in autumn.']]
# [["When the fruits are ripe in autumn, they don't need to be harvested", 'The fruit is delicious when ripe in autumn.'], ["When the fruits are ripe in autumn, they don't need to be harvested", 'If the fruit is not picked in time, it will fall and rot.']]
# [["When the fruits are ripe in autumn, they don't need to be harvested", 'The fruit is delicious when ripe in autumn.'], ["When the fruits are ripe in autumn, they don't need to be harvested", 'If the fruit is not picked in time, it will fall and rot.'], ["When the fruits are ripe in autumn, they don't need to be harvested", 'Autumn is the harvest season for some fruits.']]
# id                                               sentence_5607
# FalseSent            Peter likes to eat white paper very much.
# OptionA                                   Paper is not edible.
# OptionB        Peter often uses paper to make paper airplanes.
# OptionC      We can draw some food which can be ate on the ...
# Name: 5606, dtype: object
# [['Peter likes to eat white paper very much.', 'Paper is not edible.']]
# [['Peter likes to eat white paper very much.', 'Paper is not edible.'], ['Peter likes to eat white paper very much.', 'Peter often uses paper to make paper airplanes.']]
# [['Peter likes to eat white paper very much.', 'Paper is not edible.'], ['Peter likes to eat white paper very much.', 'Peter often uses paper to make paper airplanes.'], ['Peter likes to eat white paper very much.', 'We can draw some food which can be ate on the white paper.']]
# id                                               sentence_7698
# FalseSent    we went to the cemetery to chat with the dead ...
# OptionA              many people think the cemetery is unlucky
# OptionB      people often hope they can talk with someone w...
# OptionC                        dead people can't speak anymore
# Name: 7697, dtype: object
# [['we went to the cemetery to chat with the dead people', 'many people think the cemetery is unlucky']]
# [['we went to the cemetery to chat with the dead people', 'many people think the cemetery is unlucky'], ['we went to the cemetery to chat with the dead people', 'people often hope they can talk with someone who is dead again']]
# [['we went to the cemetery to chat with the dead people', 'many people think the cemetery is unlucky'], ['we went to the cemetery to chat with the dead people', 'people often hope they can talk with someone who is dead again'], ['we went to the cemetery to chat with the dead people', "dead people can't speak anymore"]]
# id                         sentence_3934
# FalseSent        My brother likes flying
# OptionA      Swimming is good for health
# OptionB          Swimming needs practice
# OptionC                   Man cannot fly
# Name: 3933, dtype: object
# [['My brother likes flying', 'Swimming is good for health']]
# [['My brother likes flying', 'Swimming is good for health'], ['My brother likes flying', 'Swimming needs practice']]
# [['My brother likes flying', 'Swimming is good for health'], ['My brother likes flying', 'Swimming needs practice'], ['My brother likes flying', 'Man cannot fly']]
# id                                               sentence_6895
# FalseSent    Transportation facilities belong to private pr...
# OptionA                         Private property is inviolable
# OptionB      Warning signs belong to transportation facilities
# OptionC      Transportation facilities are public property ...
# Name: 6894, dtype: object
# [['Transportation facilities belong to private property', 'Private property is inviolable']]
# [['Transportation facilities belong to private property', 'Private property is inviolable'], ['Transportation facilities belong to private property', 'Warning signs belong to transportation facilities']]
# [['Transportation facilities belong to private property', 'Private property is inviolable'], ['Transportation facilities belong to private property', 'Warning signs belong to transportation facilities'], ['Transportation facilities belong to private property', 'Transportation facilities are public property to ensure the safe operation of the transportation system.']]
# id                                               sentence_5670
# FalseSent    He wants to drink water because he is very hungry
# OptionA      People need to drink water and eat food every ...
# OptionB      People who don't eat food for a few days becom...
# OptionC      When you are hungry, you should eat rather tha...
# Name: 5669, dtype: object
# [['He wants to drink water because he is very hungry', 'People need to drink water and eat food every day.']]
# [['He wants to drink water because he is very hungry', 'People need to drink water and eat food every day.'], ['He wants to drink water because he is very hungry', "People who don't eat food for a few days become very hungry"]]
# [['He wants to drink water because he is very hungry', 'People need to drink water and eat food every day.'], ['He wants to drink water because he is very hungry', "People who don't eat food for a few days become very hungry"], ['He wants to drink water because he is very hungry', 'When you are hungry, you should eat rather than drink water.']]
# id                                sentence_1809
# FalseSent        He ate tomato soup with a fork
# OptionA      people have more spoons than forks
# OptionB      the fork would not hold the liquid
# OptionC                  most people hate forks
# Name: 1808, dtype: object
# [['He ate tomato soup with a fork', 'people have more spoons than forks']]
# [['He ate tomato soup with a fork', 'people have more spoons than forks'], ['He ate tomato soup with a fork', 'the fork would not hold the liquid']]
# [['He ate tomato soup with a fork', 'people have more spoons than forks'], ['He ate tomato soup with a fork', 'the fork would not hold the liquid'], ['He ate tomato soup with a fork', 'most people hate forks']]
# id                                           sentence_7798
# FalseSent    in old age, muscles go through a growth spurt
# OptionA             muscles develop very slowly in old age
# OptionB      people still use muscles every day in old age
# OptionC               people don't have muscles in old age
# Name: 7797, dtype: object
# [['in old age, muscles go through a growth spurt', 'muscles develop very slowly in old age']]
# [['in old age, muscles go through a growth spurt', 'muscles develop very slowly in old age'], ['in old age, muscles go through a growth spurt', 'people still use muscles every day in old age']]
# [['in old age, muscles go through a growth spurt', 'muscles develop very slowly in old age'], ['in old age, muscles go through a growth spurt', 'people still use muscles every day in old age'], ['in old age, muscles go through a growth spurt', "people don't have muscles in old age"]]
# id                                               sentence_5702
# FalseSent                      Little sheep like to eat stones
# OptionA      Cocks sometimes eat some stones to help themse...
# OptionB      Sheep can provide a lot of wool for human beings.
# OptionC               Little sheep will die if they eat stones
# Name: 5701, dtype: object
# [['Little sheep like to eat stones', 'Cocks sometimes eat some stones to help themselves digest.']]
# [['Little sheep like to eat stones', 'Cocks sometimes eat some stones to help themselves digest.'], ['Little sheep like to eat stones', 'Sheep can provide a lot of wool for human beings.']]
# [['Little sheep like to eat stones', 'Cocks sometimes eat some stones to help themselves digest.'], ['Little sheep like to eat stones', 'Sheep can provide a lot of wool for human beings.'], ['Little sheep like to eat stones', 'Little sheep will die if they eat stones']]
# id                                sentence_3574
# FalseSent                         Cat has wings
# OptionA      The cat has no wings and can't fly
# OptionB                Cats will eat bird wings
# OptionC        Animal wings can become cat food
# Name: 3573, dtype: object
# [['Cat has wings', "The cat has no wings and can't fly"]]
# [['Cat has wings', "The cat has no wings and can't fly"], ['Cat has wings', 'Cats will eat bird wings']]
# [['Cat has wings', "The cat has no wings and can't fly"], ['Cat has wings', 'Cats will eat bird wings'], ['Cat has wings', 'Animal wings can become cat food']]
# id                                            sentence_678
# FalseSent                 There was a truck moving at sea.
# OptionA                         Trucks do not move at sea.
# OptionB                        Trucks move better on land.
# OptionC      It is not common to see trucks moving at sea.
# Name: 677, dtype: object
# [['There was a truck moving at sea.', 'Trucks do not move at sea.']]
# [['There was a truck moving at sea.', 'Trucks do not move at sea.'], ['There was a truck moving at sea.', 'Trucks move better on land.']]
# [['There was a truck moving at sea.', 'Trucks do not move at sea.'], ['There was a truck moving at sea.', 'Trucks move better on land.'], ['There was a truck moving at sea.', 'It is not common to see trucks moving at sea.']]
# id                                         sentence_3530
# FalseSent    Every single kid loved loudly and fiercely.
# OptionA                        kids don't love laughing.
# OptionB               Kids don't love each other deeply.
# OptionC                    love isn't measured by voice.
# Name: 3529, dtype: object
# [['Every single kid loved loudly and fiercely.', "kids don't love laughing."]]
# [['Every single kid loved loudly and fiercely.', "kids don't love laughing."], ['Every single kid loved loudly and fiercely.', "Kids don't love each other deeply."]]
# [['Every single kid loved loudly and fiercely.', "kids don't love laughing."], ['Every single kid loved loudly and fiercely.', "Kids don't love each other deeply."], ['Every single kid loved loudly and fiercely.', "love isn't measured by voice."]]
# id                             sentence_5381
# FalseSent     Wood boards are made of rubber
# OptionA      Rubber contains many varieties.
# OptionB        Rubber does not contain wood.
# OptionC       Rubber can be used in industry
# Name: 5380, dtype: object
# [['Wood boards are made of rubber', 'Rubber contains many varieties.']]
# [['Wood boards are made of rubber', 'Rubber contains many varieties.'], ['Wood boards are made of rubber', 'Rubber does not contain wood.']]
# [['Wood boards are made of rubber', 'Rubber contains many varieties.'], ['Wood boards are made of rubber', 'Rubber does not contain wood.'], ['Wood boards are made of rubber', 'Rubber can be used in industry']]
# id                                         sentence_3354
# FalseSent              It's a shame to accept the honor.
# OptionA                     We don't deserve the honors.
# OptionB                We are satisfied with the honors.
# OptionC      We always feel proud when accepting honors.
# Name: 3353, dtype: object
# [["It's a shame to accept the honor.", "We don't deserve the honors."]]
# [["It's a shame to accept the honor.", "We don't deserve the honors."], ["It's a shame to accept the honor.", 'We are satisfied with the honors.']]
# [["It's a shame to accept the honor.", "We don't deserve the honors."], ["It's a shame to accept the honor.", 'We are satisfied with the honors.'], ["It's a shame to accept the honor.", 'We always feel proud when accepting honors.']]
# id                                               sentence_3003
# FalseSent                  The boy likes swimming in an ocean.
# OptionA      Swimming in the ocean is too dangerous for the...
# OptionB                The boy will lose his way in the ocean.
# OptionC                The boy can't get support in the ocean.
# Name: 3002, dtype: object
# [['The boy likes swimming in an ocean.', 'Swimming in the ocean is too dangerous for the boy.']]
# [['The boy likes swimming in an ocean.', 'Swimming in the ocean is too dangerous for the boy.'], ['The boy likes swimming in an ocean.', 'The boy will lose his way in the ocean.']]
# [['The boy likes swimming in an ocean.', 'Swimming in the ocean is too dangerous for the boy.'], ['The boy likes swimming in an ocean.', 'The boy will lose his way in the ocean.'], ['The boy likes swimming in an ocean.', "The boy can't get support in the ocean."]]
# id                                   sentence_4678
# FalseSent              paper would be dry in water
# OptionA      water is not enough to make paper wet
# OptionB                 the paper can absorb water
# OptionC            few paper can keep dry in water
# Name: 4677, dtype: object
# [['paper would be dry in water', 'water is not enough to make paper wet']]
# [['paper would be dry in water', 'water is not enough to make paper wet'], ['paper would be dry in water', 'the paper can absorb water']]
# [['paper would be dry in water', 'water is not enough to make paper wet'], ['paper would be dry in water', 'the paper can absorb water'], ['paper would be dry in water', 'few paper can keep dry in water']]
# id                                               sentence_6944
# FalseSent                           He likes to travel by cat.
# OptionA      Cats are so small that they can't travel on th...
# OptionB            when traveling, people can bring their cats
# OptionC      A cat is a very sticky animal and liked by man...
# Name: 6943, dtype: object
# [['He likes to travel by cat.', "Cats are so small that they can't travel on their bikes."]]
# [['He likes to travel by cat.', "Cats are so small that they can't travel on their bikes."], ['He likes to travel by cat.', 'when traveling, people can bring their cats']]
# [['He likes to travel by cat.', "Cats are so small that they can't travel on their bikes."], ['He likes to travel by cat.', 'when traveling, people can bring their cats'], ['He likes to travel by cat.', 'A cat is a very sticky animal and liked by many people.']]
# id                                      sentence_2433
# FalseSent               She took her fish for a walk.
# OptionA      Fish do not need to be taken for a walk.
# OptionB         Fish have scales while dogs have fur.
# OptionC                  Dogs and fish can both swim.
# Name: 2432, dtype: object
# [['She took her fish for a walk.', 'Fish do not need to be taken for a walk.']]
# [['She took her fish for a walk.', 'Fish do not need to be taken for a walk.'], ['She took her fish for a walk.', 'Fish have scales while dogs have fur.']]
# [['She took her fish for a walk.', 'Fish do not need to be taken for a walk.'], ['She took her fish for a walk.', 'Fish have scales while dogs have fur.'], ['She took her fish for a walk.', 'Dogs and fish can both swim.']]
# id                                            sentence_4162
# FalseSent                 a volcano was built near my house
# OptionA                     my house locates near a volcano
# OptionB      the picture is about a house near the volcano.
# OptionC                   human cannot build a volcano now.
# Name: 4161, dtype: object
# [['a volcano was built near my house', 'my house locates near a volcano']]
# [['a volcano was built near my house', 'my house locates near a volcano'], ['a volcano was built near my house', 'the picture is about a house near the volcano.']]
# [['a volcano was built near my house', 'my house locates near a volcano'], ['a volcano was built near my house', 'the picture is about a house near the volcano.'], ['a volcano was built near my house', 'human cannot build a volcano now.']]
# id                                         sentence_7397
# FalseSent    he closes his eyes while reading a magazine
# OptionA        you cannot see anything with closing eyes
# OptionB                       eyes will feel comfortable
# OptionC                   magazine do not give out light
# Name: 7396, dtype: object
# [['he closes his eyes while reading a magazine', 'you cannot see anything with closing eyes']]
# [['he closes his eyes while reading a magazine', 'you cannot see anything with closing eyes'], ['he closes his eyes while reading a magazine', 'eyes will feel comfortable']]
# [['he closes his eyes while reading a magazine', 'you cannot see anything with closing eyes'], ['he closes his eyes while reading a magazine', 'eyes will feel comfortable'], ['he closes his eyes while reading a magazine', 'magazine do not give out light']]
# id                                    sentence_5508
# FalseSent    There are many cats flying in the sky.
# OptionA               Cats are incapable of flying.
# OptionB              Cats have no wings for flying.
# OptionC                  Cats eat birds in the sky.
# Name: 5507, dtype: object
# [['There are many cats flying in the sky.', 'Cats are incapable of flying.']]
# [['There are many cats flying in the sky.', 'Cats are incapable of flying.'], ['There are many cats flying in the sky.', 'Cats have no wings for flying.']]
# [['There are many cats flying in the sky.', 'Cats are incapable of flying.'], ['There are many cats flying in the sky.', 'Cats have no wings for flying.'], ['There are many cats flying in the sky.', 'Cats eat birds in the sky.']]
# id                                               sentence_4104
# FalseSent        His words are strongly impressed on my table.
# OptionA      he is impressed by the words puzzle on the table.
# OptionB                        words do not impressed on table
# OptionC         his words are impressing on negotiating table.
# Name: 4103, dtype: object
# [['His words are strongly impressed on my table.', 'he is impressed by the words puzzle on the table.']]
# [['His words are strongly impressed on my table.', 'he is impressed by the words puzzle on the table.'], ['His words are strongly impressed on my table.', 'words do not impressed on table']]
# [['His words are strongly impressed on my table.', 'he is impressed by the words puzzle on the table.'], ['His words are strongly impressed on my table.', 'words do not impressed on table'], ['His words are strongly impressed on my table.', 'his words are impressing on negotiating table.']]
# id                                            sentence_2933
# FalseSent                  The suspect is tried in the gym.
# OptionA                  The gym isn't as big as the court.
# OptionB                     The suspect don't like the gym.
# OptionC      The gym isn't the right place to try suspects.
# Name: 2932, dtype: object
# [['The suspect is tried in the gym.', "The gym isn't as big as the court."]]
# [['The suspect is tried in the gym.', "The gym isn't as big as the court."], ['The suspect is tried in the gym.', "The suspect don't like the gym."]]
# [['The suspect is tried in the gym.', "The gym isn't as big as the court."], ['The suspect is tried in the gym.', "The suspect don't like the gym."], ['The suspect is tried in the gym.', "The gym isn't the right place to try suspects."]]
# id                                               sentence_5860
# FalseSent                          I made a fire after cooking
# OptionA                   fire can be dangerous during cooking
# OptionB                                People use fire to cook
# OptionC      The first time people use fire to cook was lon...
# Name: 5859, dtype: object
# [['I made a fire after cooking', 'fire can be dangerous during cooking']]
# [['I made a fire after cooking', 'fire can be dangerous during cooking'], ['I made a fire after cooking', 'People use fire to cook']]
# [['I made a fire after cooking', 'fire can be dangerous during cooking'], ['I made a fire after cooking', 'People use fire to cook'], ['I made a fire after cooking', 'The first time people use fire to cook was long times ago']]
# id                                               sentence_1612
# FalseSent                 The sun is not yellow; it's chicken.
# OptionA                                 Chicken is not a color
# OptionB      Female chickens are called hens and male chick...
# OptionC      Yellow is a popular color during Easter holida...
# Name: 1611, dtype: object
# [["The sun is not yellow; it's chicken.", 'Chicken is not a color']]
# [["The sun is not yellow; it's chicken.", 'Chicken is not a color'], ["The sun is not yellow; it's chicken.", 'Female chickens are called hens and male chickens are called roosters.']]
# [["The sun is not yellow; it's chicken.", 'Chicken is not a color'], ["The sun is not yellow; it's chicken.", 'Female chickens are called hens and male chickens are called roosters.'], ["The sun is not yellow; it's chicken.", 'Yellow is a popular color during Easter holiday celebrations.']]
# id                                  sentence_4281
# FalseSent               monkeys like to eat grass
# OptionA                  monkeys do not eat grass
# OptionB      grass is green and monkeys are brown
# OptionC      there are some grass next to monkeys
# Name: 4280, dtype: object
# [['monkeys like to eat grass', 'monkeys do not eat grass']]
# [['monkeys like to eat grass', 'monkeys do not eat grass'], ['monkeys like to eat grass', 'grass is green and monkeys are brown']]
# [['monkeys like to eat grass', 'monkeys do not eat grass'], ['monkeys like to eat grass', 'grass is green and monkeys are brown'], ['monkeys like to eat grass', 'there are some grass next to monkeys']]
# id                                               sentence_5736
# FalseSent                   I put my books in the refrigerator
# OptionA                            shelf is used to hold books
# OptionB            a home usually has a refrigerator and shelf
# OptionC      generally, refrigerators are more expensive th...
# Name: 5735, dtype: object
# [['I put my books in the refrigerator', 'shelf is used to hold books']]
# [['I put my books in the refrigerator', 'shelf is used to hold books'], ['I put my books in the refrigerator', 'a home usually has a refrigerator and shelf']]
# [['I put my books in the refrigerator', 'shelf is used to hold books'], ['I put my books in the refrigerator', 'a home usually has a refrigerator and shelf'], ['I put my books in the refrigerator', 'generally, refrigerators are more expensive than shelf']]
# id                                               sentence_7763
# FalseSent    some ingredients are expensive because it's co...
# OptionA                     nobody likes expensive ingredients
# OptionB                     easy to get will make things cheap
# OptionC        photos of expensive ingredients are very common
# Name: 7762, dtype: object
# [["some ingredients are expensive because it's common", 'nobody likes expensive ingredients']]
# [["some ingredients are expensive because it's common", 'nobody likes expensive ingredients'], ["some ingredients are expensive because it's common", 'easy to get will make things cheap']]
# [["some ingredients are expensive because it's common", 'nobody likes expensive ingredients'], ["some ingredients are expensive because it's common", 'easy to get will make things cheap'], ["some ingredients are expensive because it's common", 'photos of expensive ingredients are very common']]
# id                                               sentence_4349
# FalseSent     we got an ambulance and rushed her to playground
# OptionA                               doctors work in hospital
# OptionB                there is an ambulance on the playground
# OptionC      ambulance takes people to hospital not playground
# Name: 4348, dtype: object
# [['we got an ambulance and rushed her to playground', 'doctors work in hospital']]
# [['we got an ambulance and rushed her to playground', 'doctors work in hospital'], ['we got an ambulance and rushed her to playground', 'there is an ambulance on the playground']]
# [['we got an ambulance and rushed her to playground', 'doctors work in hospital'], ['we got an ambulance and rushed her to playground', 'there is an ambulance on the playground'], ['we got an ambulance and rushed her to playground', 'ambulance takes people to hospital not playground']]
# id                                               sentence_5680
# FalseSent                       Fish can survive without water
# OptionA                            fish cannot leave the water
# OptionB      Many people are very worried about the surviva...
# OptionC                  Fish in nature live a very happy life
# Name: 5679, dtype: object
# [['Fish can survive without water', 'fish cannot leave the water']]
# [['Fish can survive without water', 'fish cannot leave the water'], ['Fish can survive without water', 'Many people are very worried about the survival status of fish in the water.']]
# [['Fish can survive without water', 'fish cannot leave the water'], ['Fish can survive without water', 'Many people are very worried about the survival status of fish in the water.'], ['Fish can survive without water', 'Fish in nature live a very happy life']]
# id                                               sentence_3838
# FalseSent    French people don't eat sugar because they are...
# OptionA                              Sugar is sweet, not spicy
# OptionB                     Sugar is accepted by French people
# OptionC         Sugar is not healthy if one eat too much of it
# Name: 3837, dtype: object
# [["French people don't eat sugar because they are too spicy", 'Sugar is sweet, not spicy']]
# [["French people don't eat sugar because they are too spicy", 'Sugar is sweet, not spicy'], ["French people don't eat sugar because they are too spicy", 'Sugar is accepted by French people']]
# [["French people don't eat sugar because they are too spicy", 'Sugar is sweet, not spicy'], ["French people don't eat sugar because they are too spicy", 'Sugar is accepted by French people'], ["French people don't eat sugar because they are too spicy", 'Sugar is not healthy if one eat too much of it']]
# id                                                sentence_606
# FalseSent        She cant hold hunger she ran in to a hospital
# OptionA           Hospital will only provide medicine not food
# OptionB       Hospital will help patience to recover their ill
# OptionC      Some patience will have to get admitted in hos...
# Name: 605, dtype: object
# [['She cant hold hunger she ran in to a hospital', 'Hospital will only provide medicine not food']]
# [['She cant hold hunger she ran in to a hospital', 'Hospital will only provide medicine not food'], ['She cant hold hunger she ran in to a hospital', 'Hospital will help patience to recover their ill']]
# [['She cant hold hunger she ran in to a hospital', 'Hospital will only provide medicine not food'], ['She cant hold hunger she ran in to a hospital', 'Hospital will help patience to recover their ill'], ['She cant hold hunger she ran in to a hospital', 'Some patience will have to get admitted in hospital']]
# id                                               sentence_3132
# FalseSent    Ben wants to teach piano because he has been p...
# OptionA      Playing the violin for a long time does not me...
# OptionB      Ben has been playing the violin for a long tim...
# OptionC      Ben thinks the payment as a piano teacher is m...
# Name: 3131, dtype: object
# [['Ben wants to teach piano because he has been playing the violin since he was five years old', 'Playing the violin for a long time does not mean Ben can play the piano']]
# [['Ben wants to teach piano because he has been playing the violin since he was five years old', 'Playing the violin for a long time does not mean Ben can play the piano'], ['Ben wants to teach piano because he has been playing the violin since he was five years old', 'Ben has been playing the violin for a long time but he likes piano better']]
# [['Ben wants to teach piano because he has been playing the violin since he was five years old', 'Playing the violin for a long time does not mean Ben can play the piano'], ['Ben wants to teach piano because he has been playing the violin since he was five years old', 'Ben has been playing the violin for a long time but he likes piano better'], ['Ben wants to teach piano because he has been playing the violin since he was five years old', 'Ben thinks the payment as a piano teacher is more decent than a violin teacher']]
# id                                               sentence_5698
# FalseSent                        Thinking can make people dull
# OptionA                    Smart and dull are usually antonyms
# OptionB        Thinking can make you more logical and smarter.
# OptionC      Thinking can help us solve some difficult prob...
# Name: 5697, dtype: object
# [['Thinking can make people dull', 'Smart and dull are usually antonyms']]
# [['Thinking can make people dull', 'Smart and dull are usually antonyms'], ['Thinking can make people dull', 'Thinking can make you more logical and smarter.']]
# [['Thinking can make people dull', 'Smart and dull are usually antonyms'], ['Thinking can make people dull', 'Thinking can make you more logical and smarter.'], ['Thinking can make people dull', 'Thinking can help us solve some difficult problems.']]
# id                                               sentence_1469
# FalseSent                  he opened a can and started to read
# OptionA                         cans and books are both opened
# OptionB                 cans have text stating the ingredients
# OptionC      cans are food material and aren't meant to be ...
# Name: 1468, dtype: object
# [['he opened a can and started to read', 'cans and books are both opened']]
# [['he opened a can and started to read', 'cans and books are both opened'], ['he opened a can and started to read', 'cans have text stating the ingredients']]
# [['he opened a can and started to read', 'cans and books are both opened'], ['he opened a can and started to read', 'cans have text stating the ingredients'], ['he opened a can and started to read', "cans are food material and aren't meant to be read"]]
# id                                               sentence_5901
# FalseSent             we held a party in the library last week
# OptionA      not everyone likes parties or studying in the ...
# OptionB      the library is a place where people read and s...
# OptionC      there are many preparations to do if you want ...
# Name: 5900, dtype: object
# [['we held a party in the library last week', 'not everyone likes parties or studying in the library']]
# [['we held a party in the library last week', 'not everyone likes parties or studying in the library'], ['we held a party in the library last week', 'the library is a place where people read and study and parties are not allowed in it']]
# [['we held a party in the library last week', 'not everyone likes parties or studying in the library'], ['we held a party in the library last week', 'the library is a place where people read and study and parties are not allowed in it'], ['we held a party in the library last week', 'there are many preparations to do if you want to hold a party']]
# id                                               sentence_3822
# FalseSent    Watching video for the whole day is good for y...
# OptionA          Watching video can help people gain knowledge
# OptionB             People can watch videos on websites or TVs
# OptionC                      Watching video harm people's eyes
# Name: 3821, dtype: object
# [['Watching video for the whole day is good for your eyes', 'Watching video can help people gain knowledge']]
# [['Watching video for the whole day is good for your eyes', 'Watching video can help people gain knowledge'], ['Watching video for the whole day is good for your eyes', 'People can watch videos on websites or TVs']]
# [['Watching video for the whole day is good for your eyes', 'Watching video can help people gain knowledge'], ['Watching video for the whole day is good for your eyes', 'People can watch videos on websites or TVs'], ['Watching video for the whole day is good for your eyes', "Watching video harm people's eyes"]]
# id                                               sentence_3750
# FalseSent    The prisoner is set free after executing his d...
# ...
# OptionB      Bottles are usually red rabbits are usually white
# OptionC                Rabbit have teeth but bottle don't have
# Name: 2167, dtype: object
# [['He  gave  a bottle to a rabbit', 'Rabbit cannot eat a bottle']]
# [['He  gave  a bottle to a rabbit', 'Rabbit cannot eat a bottle'], ['He  gave  a bottle to a rabbit', 'Bottles are usually red rabbits are usually white']]
# [['He  gave  a bottle to a rabbit', 'Rabbit cannot eat a bottle'], ['He  gave  a bottle to a rabbit', 'Bottles are usually red rabbits are usually white'], ['He  gave  a bottle to a rabbit', "Rabbit have teeth but bottle don't have"]]
# id                                               sentence_7617
# FalseSent               I wore my wedding ring on my left foot
# OptionA                        ring should be worn on the hand
# OptionB      walking with a ring on your feet is very uncom...
# OptionC                     wedding rings need to be kept safe
# Name: 7616, dtype: object
# [['I wore my wedding ring on my left foot', 'ring should be worn on the hand']]
# [['I wore my wedding ring on my left foot', 'ring should be worn on the hand'], ['I wore my wedding ring on my left foot', 'walking with a ring on your feet is very uncomfortable']]
# [['I wore my wedding ring on my left foot', 'ring should be worn on the hand'], ['I wore my wedding ring on my left foot', 'walking with a ring on your feet is very uncomfortable'], ['I wore my wedding ring on my left foot', 'wedding rings need to be kept safe']]
# id                                               sentence_2534
# FalseSent          He put his mustache into the computer form.
# OptionA      The computer was a PC but his mustache was brown.
# OptionB      A mustache cannot be entered into a computer f...
# OptionC        A computer can only use one mustache at a time.
# Name: 2533, dtype: object
# [['He put his mustache into the computer form.', 'The computer was a PC but his mustache was brown.']]
# [['He put his mustache into the computer form.', 'The computer was a PC but his mustache was brown.'], ['He put his mustache into the computer form.', 'A mustache cannot be entered into a computer form.']]
# [['He put his mustache into the computer form.', 'The computer was a PC but his mustache was brown.'], ['He put his mustache into the computer form.', 'A mustache cannot be entered into a computer form.'], ['He put his mustache into the computer form.', 'A computer can only use one mustache at a time.']]
# id                            sentence_1696
# FalseSent          He delivered a baby girl
# OptionA         A baby don't deliver a baby
# OptionB           Only women deliver babies
# OptionC      Some babies cry after delivery
# Name: 1695, dtype: object
# [['He delivered a baby girl', "A baby don't deliver a baby"]]
# [['He delivered a baby girl', "A baby don't deliver a baby"], ['He delivered a baby girl', 'Only women deliver babies']]
# [['He delivered a baby girl', "A baby don't deliver a baby"], ['He delivered a baby girl', 'Only women deliver babies'], ['He delivered a baby girl', 'Some babies cry after delivery']]
# id                                               sentence_1096
# FalseSent                 You can heat a turkey in the freezer
# OptionA      The freezer is too cold, and therefore, cannot...
# OptionB                       Freezers are spacious, and clean
# OptionC                           Freezers are nice and toasty
# Name: 1095, dtype: object
# [['You can heat a turkey in the freezer', 'The freezer is too cold, and therefore, cannot heat a turkey']]
# [['You can heat a turkey in the freezer', 'The freezer is too cold, and therefore, cannot heat a turkey'], ['You can heat a turkey in the freezer', 'Freezers are spacious, and clean']]
# [['You can heat a turkey in the freezer', 'The freezer is too cold, and therefore, cannot heat a turkey'], ['You can heat a turkey in the freezer', 'Freezers are spacious, and clean'], ['You can heat a turkey in the freezer', 'Freezers are nice and toasty']]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df_dr = X_train.apply(lambda row: ensemble(row), axis=1)
#       3 print(df_dr)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [17], in <lambda>(row)
# ----> 1 df_dr = X_train.apply(lambda row: ensemble(row), axis=1)
#       3 print(df_dr)
#
# Input In [15], in ensemble(example)
#       8 bert_inputs = bert_tokenizer(prompts, return_tensors="pt", padding=True)
#      10 labels = torch.tensor(0).unsqueeze(0)
# ---> 12 bert_outputs = bert_model(**{k: v.unsqueeze(0) for k, v in bert_inputs.items()}, labels=labels)
#      14 predicted_class = bert_outputs.logits.argmax().item()
#      16 return answers[predicted_class]
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:1677, in BertForMultipleChoice.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1670 position_ids = position_ids.view(-1, position_ids.size(-1)) if position_ids is not None else None
#    1671 inputs_embeds = (
#    1672     inputs_embeds.view(-1, inputs_embeds.size(-2), inputs_embeds.size(-1))
#    1673     if inputs_embeds is not None
#    1674     else None
#    1675 )
# -> 1677 outputs = self.bert(
#    1678     input_ids,
#    1679     attention_mask=attention_mask,
#    1680     token_type_ids=token_type_ids,
#    1681     position_ids=position_ids,
#    1682     head_mask=head_mask,
#    1683     inputs_embeds=inputs_embeds,
#    1684     output_attentions=output_attentions,
#    1685     output_hidden_states=output_hidden_states,
#    1686     return_dict=return_dict,
#    1687 )
#    1689 pooled_output = outputs[1]
#    1691 pooled_output = self.dropout(pooled_output)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:1021, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1012 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1014 embedding_output = self.embeddings(
#    1015     input_ids=input_ids,
#    1016     position_ids=position_ids,
#    (...)
#    1019     past_key_values_length=past_key_values_length,
#    1020 )
# -> 1021 encoder_outputs = self.encoder(
#    1022     embedding_output,
#    1023     attention_mask=extended_attention_mask,
#    1024     head_mask=head_mask,
#    1025     encoder_hidden_states=encoder_hidden_states,
#    1026     encoder_attention_mask=encoder_extended_attention_mask,
#    1027     past_key_values=past_key_values,
#    1028     use_cache=use_cache,
#    1029     output_attentions=output_attentions,
#    1030     output_hidden_states=output_hidden_states,
#    1031     return_dict=return_dict,
#    1032 )
#    1033 sequence_output = encoder_outputs[0]
#    1034 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:610, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     601     layer_outputs = torch.utils.checkpoint.checkpoint(
#     602         create_custom_forward(layer_module),
#     603         hidden_states,
#    (...)
#     607         encoder_attention_mask,
#     608     )
#     609 else:
# --> 610     layer_outputs = layer_module(
#     611         hidden_states,
#     612         attention_mask,
#     613         layer_head_mask,
#     614         encoder_hidden_states,
#     615         encoder_attention_mask,
#     616         past_key_value,
#     617         output_attentions,
#     618     )
#     620 hidden_states = layer_outputs[0]
#     621 if use_cache:
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:496, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     484 def forward(
#     485     self,
#     486     hidden_states: torch.Tensor,
#    (...)
#     493 ) -> Tuple[torch.Tensor]:
#     494     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     495     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 496     self_attention_outputs = self.attention(
#     497         hidden_states,
#     498         attention_mask,
#     499         head_mask,
#     500         output_attentions=output_attentions,
#     501         past_key_value=self_attn_past_key_value,
#     502     )
#     503     attention_output = self_attention_outputs[0]
#     505     # if decoder, the last output is tuple of self-attn cache
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:426, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     416 def forward(
#     417     self,
#     418     hidden_states: torch.Tensor,
#    (...)
#     424     output_attentions: Optional[bool] = False,
#     425 ) -> Tuple[torch.Tensor]:
# --> 426     self_outputs = self.self(
#     427         hidden_states,
#     428         attention_mask,
#     429         head_mask,
#     430         encoder_hidden_states,
#     431         encoder_attention_mask,
#     432         past_key_value,
#     433         output_attentions,
#     434     )
#     435     attention_output = self.output(self_outputs[0], hidden_states)
#     436     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:307, in BertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     305     value_layer = torch.cat([past_key_value[1], value_layer], dim=2)
#     306 else:
# --> 307     key_layer = self.transpose_for_scores(self.key(hidden_states))
#     308     value_layer = self.transpose_for_scores(self.value(hidden_states))
#     310 query_layer = self.transpose_for_scores(mixed_query_layer)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
